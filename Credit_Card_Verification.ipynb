# %% [markdown]
# <a href="https://colab.research.google.com/github/krixtofferxon/MyPython/blob/main/Credit_Card_Verification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
creditCardNumber = '5520 5050 6076 4032'
creditCardNumberClean = creditCardNumber.replace(' ', '')


def creditCardValidate(cardNumber):
  cardProvider = 'Unknown'

  firstDigit = cardNumber[0]
  firstTwoDigits = int(cardNumber[:2])
  firstFourDigits = int(cardNumber[:4])

  if firstDigit == '4':
    cardProvider = 'Visa'
  elif (51 <= firstTwoDigits <= 55) or (2221 <= firstFourDigits <= 2720):
    cardProvider = 'MasterCard'
  elif cardNumber[0] == '3' and cardNumber[1] == '7':
    cardProvider = 'American Express'
  elif cardNumber[0] == '6':
    cardProvider = 'Discover'
  else:
    cardProvider = 'Unknown'
  return cardProvider

  luhnSum = 0
  numDigits = len(cardNumber)
  oddeven = numDigits & 1

print(creditCardValidate(creditCardNumberClean))
# Out:
# MasterCard
