# %% [markdown]
# <a href="https://colab.research.google.com/github/krixtofferxon/MyPython/blob/main/Make_Your_Own_Python_Text_Adventure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Source code for game.py

# %%
def play():
  inventory = [Dagger(), 'Gold(5)', 'Crusty Bread']
  print("Escape from Cave Terror!")
  while True:
    actionInput = getPlayerCommand()
    if actionInput in ['n', 'N']:
      print("Go North!")
    elif actionInput in ['s', 'S']:
      print("Go South!")
    elif actionInput in ['e', 'E']:
      print("Go East!")
    elif actionInput in ['w', 'W']:
      print("Go West!")
    elif actionInput in ['i', 'I']:
      print("Inventory:")
      for item in inventory:
        print('*' + str(item))
        #print(inventory)
    else:
      print("Invalid action!")

def getPlayerCommand():
  return input("What would you like to do? ")

class Weapon:
  def __str__(self):
    return self.name + ': ' + self.description

class Rock(Weapon):
  def __init__ (self):
    self.name = "Rock"
    self.description = "A fist-sized rock, suitable for bludgeoning."
    self.damage = 5

class Dagger(Weapon):
   def __init__ (self):
    self.name = "Dagger"
    self.description = "A small dagger with some rust. Somewhat more dangerous than a rock."
    self.damage = 10

class RustySword(Weapon):
   def __init__ (self):
    self.name = "Rusty Sword"
    self.description = "This sword is showing its age, but still has some fight in it."
    self.damage = 20


play()
# Out:
# Escape from Cave Terror!
# What would you like to do? I
# Inventory:
# *Dagger: A small dagger with some rust. Somewhat more dangerous than a rock.
# *Gold(5)
# *Crusty Bread
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3181241556.py in <cell line: 0>()
#      46
#      47
# ---> 48 play()
#
# /tmp/ipython-input-3181241556.py in play()
#       3   print("Escape from Cave Terror!")
#       4   while True:
# ----> 5     actionInput = getPlayerCommand()
#       6     if actionInput in ['n', 'N']:
#       7       print("Go North!")
#
# /tmp/ipython-input-3181241556.py in getPlayerCommand()
#      21
#      22 def getPlayerCommand():
# ---> 23   return input("What would you like to do? ")
#      24
#      25 class Weapon:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...

# %% [markdown]
# Source code for echo.py

# %%
userInput = input("Type some text: ")
print(userInput)
type(userInput)
# Out:
# Type some text: 5
# 5
# str

# %%
n = 5
print(n)
print('n')
# Out:
# 5
# n

# %%
5 == 5
# Out:
# True

# %% [markdown]
# Source Code for ages.py

# %%
personsAge = input("How old are you?")
personsAge = int(personsAge)
if personsAge < 10:
  print("You are young!")
elif personsAge < 20:
  print("You are a young adult!")
elif personsAge < 60:
  print("You are an adult!")
elif personsAge >= 60:
  print("You are a senior!")
else:
  print("Invalid age!")
# Out:
# How old are you?100
# You are a senior!

# %%
place = "white house"
importantPlace = place.title()
print(importantPlace)
# Out:
# White House

# %% [markdown]
# Source Code for helloName.py

# %%
def sayHello(name):
  print("Hello, " + name)

userName = input("What is your name?")
sayHello(userName)

answer = input("Would you like another greeting?")
if answer == 'y':
  sayHello(userName)

#Trivia: Functions can have up to 255 parameters. Please don't write functionsd with 255 parameters!
# Out:
# What is your name?Sam
# Hello, Sam
# Would you like another greeting?y
# Hello, Sam

# %%
# Homework on Chapter 6 List

len('Hello, World!')
#len({})

myList = ['A', 'B', 'C', 'D']
lastPosition = len(myList) - 1
myList[lastPosition]

myList = ['John', 'Jack', 'Ashton', 'Loretta']
#myList.index('Buffalo')

planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
#planets = ['Mercury', 'Venus', 'Earth']
#planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter']
#(len(planets)/2)
print(planets[(len(planets)//2)])

list(range(5))
list(range(3,7))
list(range(7,3))
list(range(-2,2))
# Out:
# Jupiter
# [-2, -1, 0, 1]

# %%
class Person:
  def __init__(self, name, age, favoriteFoods):
    self.name = name
    self.age = age
    self.favoriteFoods = favoriteFoods
