# %% [markdown]
# <a href="https://colab.research.google.com/github/krixtofferxon/MyPython/blob/main/Make_Your_Own_Python_Text_Adventure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Source code for items.py

# %%
class Weapon:
  def __init__(self):
    raise NotImplementedError("Do not create raw Weapon objects.")
  def __str__(self):
    return self.name + ': ' + self.description

class Rock(Weapon):
  def __init__ (self):
    self.name = "Rock"
    self.description = "A fist-sized rock, suitable for bludgeoning."
    self.damage = 5

class Dagger(Weapon):
   def __init__ (self):
    self.name = "Dagger"
    self.description = "A small dagger with some rust. Somewhat more dangerous than a rock."
    self.damage = 10

class RustySword(Weapon):
   def __init__ (self):
    self.name = "Rusty Sword"
    self.description = "This sword is showing its age, but still has some fight in it."
    self.damage = 20

# To raise intentional error to test the raise
# axe = Weapon()
# print(axe)

class Consumable:
  def __init__(self):
    raise NotImplementedError("Do not create raw Consumable objects.")

  def __str__(self):
    return "{} (+{} HP)".format(self.name, self.healingValue)

class CrustyBread(Consumable):
  def __init__(self):
    self.name = "Crusty Bread"
    self.healingValue = 10

# %% [markdown]
# Source code for player.py

# %%
# import items.py # Enable this if working as true multiple files
# import world.py # Enable this if working as true multiple files

class Player:
  def __init__(self):
    self.inventory = [Rock(), Dagger(), 'Gold(5)', CrustyBread()]
    #self.inventory = [items.Rock(), items.Dagger(), 'Gold(5)', 'Crusty Bread']

    self.x = 1
    self.y = 2
    self.hp = 100

  def printInventory(self):
    print("Inventory:")
    for item in self.inventory:
      print('*' + str(item))
    bestWeapon = self.mostPowerfulWeapon()
    print("Your best weapon is your {}".format(bestWeapon))

  def mostPowerfulWeapon(self):
    maxDamage = 0
    bestWeapon = None
    for item in self.inventory:
      try:
        if item.damage > maxDamage:
          bestWeapon = item
          maxDamage = item.damage
      except AttributeError:
        pass
    return bestWeapon

  def move(self, dx, dy):
    self.x += dx
    self.y += dy

  def moveNorth(self):
    self.move(dx=0, dy=-1)

  def moveSouth(self):
    self.move(dx=0, dy=1)

  def moveEast(self):
    self.move(dx=1, dy=0)

  def moveWest(self):
    self.move(dx=-1, dy=0)

  def printLocationInfo(self):
    return "You are currently at position ({}, {}).".format(self.x, self.y)

  def attack(self):
    bestWeapon = self.mostPowerfulWeapon()
    room = tileAt(self.x, self.y)
    enemy = room.enemy
    print("You use your {} against {}!".format(bestWeapon.name, enemy.name))
    enemy.hp -= bestWeapon.damage
    if not enemy.isAlive():
      print("You killed {}!".format(enemy.name))
    else:
      print("{} HP is {}.".format(enemy.name, enemy.hp))

  def heal(self):
    consumables = [item for item in self.inventory if isinstance(item, Consumable)]
    # [whatWeWant FOR thing IN iterable IF condition]
    # whatWeWant: What ends up in the new list. This is often just the thing in the iterable,
    #             but we can modify the thing if we want.
    # thing: The object in the iterable.
    # iterable: Something that can be passed to a for-each loop, such as as list, range, or tuple.
    # condition (optional): A condition to limit what is added to the list.

    if not consumables:
      print("You don't have any items to heal you!")
      return

    for i, item in enumerate(consumables, 1): #Start counting at one for display
      print("Choose an item to use to heal: ")
      print("{}. {}".format(i, item))

    valid = False
    while not valid:
      choice = input("")
      try:
        toEat = consumables[int(choice) - 1]
        self.hp = min(100, self.hp + toEat.healingValue)
        # min() returns the lesser of the two values. This caps the player's HP to 100.
        self.inventory.remove(toEat)
        print("Current HP: {}".format(self.hp))
        valid = True
      except (IndexError, ValueError):
        print("Invalid choice, try again.")

# %% [markdown]
# Source code for enemies.py

# %%
class Enemy:
  def __init__(self):
    raise NotImplementedError("Do not create raw Enemy objects.")

  def __str__(self):
    return self.name

  def isAlive(self):
    return self.hp > 0

class GiantSpider(Enemy):
  def __init__(self):
    self.name = "Jimmy Santos"
    #self.name = "Giant Spider"
    self.hp = 10
    self.damage = 2

class Orge(Enemy):
  def __init__(self):
    self.name = "Orge"
    self.hp = 30
    self.damage = 10

class BatColony(Enemy):
  def __init__(self):
    self.name = "Bat Colony"
    self.hp = 100
    self.damage = 4

class RockMonster(Enemy):
  def __init__(self):
    self.name = "Rock Monster"
    self.hp = 80
    self.damage = 15

# %% [markdown]
# Source code for world.py

# %%
import random

class MapTile:
  def __init__(self, x, y):
    self.x = x
    self.y = y

  def introText(self):
    raise NotImplementedError("Create a subclass instead!")

  def modifyPlayer(self, player):
    pass

class StartTile(MapTile):
  def introText(self):
    return """
    You find yourself in a cave with a flickering torch on the wall.
    You can make out four paths, each equally as dark and foreboding.
    """

class BoringTile(MapTile):
  def introText(self):
    return """
    This is a very boring part of the cave.
    """

class VictoryTile(MapTile):
  def introText(self):
    return """
    You see a bright light in the distance...
    ... it grows as you get closer! It's sunlight!


    Victory is yours!
    """

# Customization Point: Adjust the numbers to make the game
# easier or harder. A harder game might use 0.40, 0.70, and 0.90, for
# example. If you have more than four enemy types, make sure you
# define the percentages for each type

class EnemyTile(MapTile):
  def __init__(self, x, y):
    r = random.random()
    if r < 0.50:
      self.enemy = GiantSpider() # enemies.GiantSpider()
      self.aliveText = """
      A {} jumps down from its web in front of you!
      """.format(self.enemy.name)
      self.deadText = """
      The corpse of a dead spider rots on the ground.
      """
    elif r < 0.80:
      self.enemy = Orge()
      self.aliveText = """
      An orge is blocking your path!
      """
      self.deadText = """
      A dead orge reminds you of your triump.
      """
    elif r < 0.95:
      self.enemy = BatColony()
      self.aliveText = """
      You hear a squeaking noise growing louder
      ...suddenly you are lost in a swarm of bats!"
      """
      self.deadText = """
      Dozens of dead bats are scattered on the ground.
      """
    else:
      self.enemy = RockMonster()
      self.aliveText = """
      You've distrubed a rock monster from his slumber!
      """
      self.deadText = """
      Defeated, the monster had reverted into an ordinary rock.
      """

    super().__init__(x, y)

  def introText(self):
    text = self.aliveText if self.enemy.isAlive() else self.deadText
    return text

    if self.enemy.isAlive():
      return "A {} with {} HP is blocking your path!".format(self.enemy, self.enemy.hp)
    else:
      return "You have found a dead {}!".format(self.enemy)

  def modifyPlayer(self, player):
    if self.enemy.isAlive():
      player.hp = player.hp - self.enemy.damage
      print("Enemy does {} damage. You have {} HP remaining.".format(self.enemy.damage, player.hp))


worldMap = [
  [BoringTile(0,0), VictoryTile(1, 0), BoringTile(2,0)],
  [BoringTile(0,1), BoringTile(1, 1), BoringTile(2,1)],
  [EnemyTile(0,2), StartTile(1,2), EnemyTile(2,2)],
  [None, BoringTile(1,3), None]

]

def tileAt(x, y):
  if x < 0 or y < 0:
    return None
  try:
    return worldMap[y][x]
  except IndexError:
    return None

# %% [markdown]
# Source code for game.py

# %%
# from player import Player # Enable this if working as true multiple files
# import world
from collections import OrderedDict

def play():
  isContinue = True
  Player01 = Player()
  print("Escape from Cave Terror!")

  while isContinue:
    room = tileAt(Player01.x, Player01.y)
    print(room.introText())
    room.modifyPlayer(Player01)

    actionInput = getPlayerCommand()
    if actionInput in ['n', 'N']:
      print("Go North!")
      Player01.moveNorth()
    elif actionInput in ['s', 'S']:
      print("Go South!")
      Player01.moveSouth()
    elif actionInput in ['e', 'E']:
      print("Go East!")
      Player01.moveEast()
    elif actionInput in ['w', 'W']:
      print("Go West!")
      Player01.moveWest()
    elif actionInput in ['i', 'I']:
      Player01.printInventory()
    elif actionInput in ['a', 'A']:
      Player01.attack()
    elif actionInput in ['h', 'H']:
      Player01.heal()
    elif actionInput in ['q', 'Q']:
      print("Quitting game!")
      isContinue = False
    else:
      print("Invalid action!")

    # print(Player01.printLocationInfo()) #Enable for easier testing of location

def getPlayerCommand():
  return input("What would you like to do? ")


def actionAdder(actionDict, hotkey, action, name):
  actionDict[hotkey.lower()] = action
  actionDict[hotkey.upper()] = action
  print("{}: {}".format(hotkey, name)

def getAvailableAction(room, player):
  actions = OrderedDict()
  print("Choose an action: ")
  if player.inventory:


play()
# Out:
# Escape from Cave Terror!
#
#     You find yourself in a cave with a flickering torch on the wall.
#     You can make out four paths, each equally as dark and foreboding.
#
# What would you like to do? w
# Go West!
#
#       An orge is blocking your path!
#
# Enemy does 10 damage. You have 90 HP remaining.
# What would you like to do? e
# Go East!
#
#     You find yourself in a cave with a flickering torch on the wall.
#     You can make out four paths, each equally as dark and foreboding.
#
# What would you like to do? e
# Go East!
#
#       A Jimmy Santos jumps down from its web in front of you!
#
# Enemy does 2 damage. You have 88 HP remaining.
# What would you like to do? q
# Quitting game!

# %% [markdown]
# -- Starting from this point, all codes are just side exercises.--

# %% [markdown]
# Source code for echo.py

# %%
userInput = input("Type some text: ")
print(userInput)
type(userInput)
# Out:
# Type some text: 5
# 5
# str

# %%
n = 5
print(n)
print('n')
# Out:
# 5
# n

# %%
5 == 5
# Out:
# True

# %% [markdown]
# Source Code for ages.py

# %%
personsAge = input("How old are you?")
personsAge = int(personsAge)
if personsAge < 10:
  print("You are young!")
elif personsAge < 20:
  print("You are a young adult!")
elif personsAge < 60:
  print("You are an adult!")
elif personsAge >= 60:
  print("You are a senior!")
else:
  print("Invalid age!")
# Out:
# How old are you?100
# You are a senior!

# %%
place = "white house"
importantPlace = place.title()
print(importantPlace)
# Out:
# White House

# %% [markdown]
# Source Code for helloName.py

# %%
def sayHello(name):
  print("Hello, " + name)

userName = input("What is your name?")
sayHello(userName)

answer = input("Would you like another greeting?")
if answer == 'y':
  sayHello(userName)

#Trivia: Functions can have up to 255 parameters. Please don't write functionsd with 255 parameters!
# Out:
# What is your name?Sam
# Hello, Sam
# Would you like another greeting?y
# Hello, Sam

# %%
# Homework on Chapter 6 List

len('Hello, World!')
#len({})

myList = ['A', 'B', 'C', 'D']
lastPosition = len(myList) - 1
myList[lastPosition]

myList = ['John', 'Jack', 'Ashton', 'Loretta']
#myList.index('Buffalo')

planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
#planets = ['Mercury', 'Venus', 'Earth']
#planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter']
#(len(planets)/2)
print(planets[(len(planets)//2)])

list(range(5))
list(range(3,7))
list(range(7,3))
list(range(-2,2))
# Out:
# Jupiter
# [-2, -1, 0, 1]

# %%
class Person:
  def __init__(self, name, age, favoriteFoods):
    self.name = name
    self.age = age
    self.favoriteFoods = favoriteFoods
